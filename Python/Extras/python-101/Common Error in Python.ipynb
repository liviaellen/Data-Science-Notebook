# %% [markdown]
# SyntaxError: Typo, wrong syntax

# %%
a = 9
a + )
# Out:
#   Cell In [1], line 2
#     a + )
#         ^
# SyntaxError: unmatched ')'

# %% [markdown]
# "Name Error" means that you need to assign a variable or define the function as instructed.

# %%
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 b
#
# NameError: name 'b' is not defined

# %% [markdown]
# ModuleNotFoundError: you have to install the packages, or you have typo in module import

# %%
import pandas2 as pd

pd.DataFrame()

#solution : !pip install pandas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 import pandas2 as pd
#       3 pd.DataFrame()
#
# ModuleNotFoundError: No module named 'pandas2'

# %% [markdown]
# "Type Error" means that your data type provided is not accurate

# %%
b = 9 
c = "hello"

b + c
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [9], line 4
#       1 b = 9
#       2 c = "hello"
# ----> 4 b + c
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# KeyError : No key
#
# -solution
# `d.get('age', "no information")`

# %%
d = {'name' : 'ellen'}
d['age']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [15], line 2
#       1 d = {'name' : 'ellen'}
# ----> 2 d['age']
#
# KeyError: 'age'

# %% [markdown]
# "Assertion Error" means that your provided solution does not match the correct answer.

# %%
a = 8
b = 9

a_plus_b = 17 

answer = 18
assert a_plus_b == 18
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In [17], line 7
#       4 a_plus_b = 17
#       6 answer = 18
# ----> 7 assert a_plus_b == 18
#
# AssertionError:

# %% [markdown]
# If your kernel freezes, click on "Kernel" then select "Restart"
